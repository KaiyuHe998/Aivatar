# %%
import os
import json
root_path = ".."
proj_required_keys = [
    'description','project_type','src_file','portfolio_src','portfolio_marker','portfolio_marker_highlight'
]

# %%
# TODO 
# 1, 完成construct json 文件生成自动维护代码
# 2, portfolio页面动态生成
# 3, memory system 根据需要读取当前页面的内容
# 4, Keyword 系统动态更新keyword, meta-keyword 根据页数创建读取位置 传送 高亮的
# 5, _ 单下划线的key是给agent的额外内容，当agent加载到该页面之后读取




# TODO 
# 1, Action Space完善
# 2, 用户操作读取记录
# 3, 主动式agent行为调用 规则

# %%
# publications

def organize_portfolio_construct(proj_type):
    publication_portfolio_construction_file = []
    project_type = proj_type
    path = os.path.join(root_path,project_type)
    project_names = os.listdir(path)
    for project_name in project_names:
        if project_name.startswith('.'):
            continue
        proj_path = os.path.join(path, project_name)
        with open(os.path.join(proj_path, 'meta.json'), 'r') as f:
            meta_file = json.load(f)
        if 'title' not in meta_file or project_name != meta_file['title']:
            meta_file['title'] = project_name
        for required_key in proj_required_keys:
            assert required_key in meta_file, f'''required key: {required_key} not in meta file, proj_path: {proj_path}'''
        portfolio_construct_meta = {}
        cleaned_meta_data = {}
        for key in meta_file:
            if not key.startswith('_'):
                # construct meta data
                construct_meta_data_keys = ['title','project_type','portfolio_src','portfolio_marker','portfolio_marker_highlight']
                if key in construct_meta_data_keys:
                    if key == 'portfolio_src':
                        value = []
                        pt_files = meta_file[key]
                        for pt_file in pt_files:
                            if len(pt_file.split('/'))>1:
                                value.append(pt_file)
                            else:
                                value.append(os.path.join(proj_path,pt_file))
                    else:
                        value = meta_file[key]
                        
                    portfolio_construct_meta.update({
                        key: value
                    })
                    
            # clean file meta data
            if key == 'portfolio_src':
                clean_meta_value = []
                portfolio_srcs = meta_file['portfolio_src']
                for portfolio_src in portfolio_srcs:
                    if len(portfolio_src.split('/'))>1:
                        clean_meta_value.append(portfolio_src)
                    else:
                        clean_meta_value.append(os.path.join(proj_path,portfolio_src))
            elif key == 'src_file':
                if meta_file['project_type'] == 'outside link':
                    clean_meta_value = meta_file[key]
                else:
                    cur_path = meta_file[key]
                    if cur_path is None:
                        clean_meta_value = None
                    elif len(cur_path.split('/'))>1:
                        clean_meta_value = os.path.join(proj_path,cur_path)
                    else:
                        clean_meta_value = cur_path
                        
                    
            else:
                clean_meta_value = meta_file[key]
            cleaned_meta_data.update({key:clean_meta_value})
        with open(os.path.join(proj_path, 'meta.json'), 'w', encoding='utf-8') as f:
            json.dump(cleaned_meta_data, f, ensure_ascii=False, indent=4)
            
        publication_portfolio_construction_file.append(portfolio_construct_meta)
    return {proj_type:publication_portfolio_construction_file}

# %%
proj_types = ['publications','projects','links']
construct_json_file = {}
for proj_type in proj_types:
    construct_json_file.update(organize_portfolio_construct(proj_type))
construct_json_file
# Out:
# {'publications': [{'title': 'Abductive Reasoning Evaluation',
#    'project_type': 'pdf',
#    'portfolio_src': ['../publications/Abductive Reasoning Evaluation/Fig1.png',
#     '../publications/Abductive Reasoning Evaluation/Fig2.png',
#     '../publications/Abductive Reasoning Evaluation/Fig3.png',
#     '../publications/Abductive Reasoning Evaluation/Fig4.png'],
#    'portfolio_marker': ['LLM',
#     'Abductive reasoning',
#     'Evaluation',
#     'Reinforcement Learning'],
#    'portfolio_marker_highlight': ['ICLR 2026（under review）']},
#   {'title': 'Eifficient RAG',
#    'project_type': 'pdf',
#    'portfolio_src': ['../publications/Eifficient RAG/Fig1.png',
#     '../publications/Eifficient RAG/Fig2.png',
#     '../publications/Eifficient RAG/Fig3.png'],
#    'portfolio_marker': ['RAG',
#     'Agentic',
#     'Reinforcement Learning',
#     'Process Rewards',
#     'Search Efficiency'],
#    'portfolio_marker_highlight': ['ICLR 2026（under review）']},
#   {'title': 'LLM hypothesis discovery survey',
#    'project_type': 'pdf',
#    'portfolio_src': ['../publications/LLM hypothesis discovery survey/Fig1.png',
#     '../publications/LLM hypothesis discovery survey/Fig2.png',
#     '../publications/LLM hypothesis discovery survey/Fig3.png',
#     '../publications/LLM hypothesis discovery survey/Fig4.png'],
#    'portfolio_marker': ['LLM Reasoning', 'LLM Learning', 'AGI'],
#    'portfolio_marker_highlight': ['TMLR survey certification']},
#   {'title': 'Contact tracing',
#    'project_type': 'pdf',
#    'portfolio_src': ['../publications/Contact tracing/Fig1.png',
#     '../publications/Contact tracing/Fig2.png',
#     '../publications/Contact tracing/Fig3.png'],
#    'portfolio_marker': ['Public Health',
#     'Epidemiology',
#     'Contact Tracing',
#     'Survey Methods',
#     'Machine Learning'],
#    'portfolio_marker_highlight': ['BMC Public Health 2024']},
#   {'title': 'IDEA',
#    'project_type': 'pdf',
#    'portfolio_src': ['../publications/IDEA/Fig1.png',
#     '../publications/IDEA/Fig2.png',
#     '../publications/IDEA/Fig3.png'],
#    'portfolio_marker': ['LLM',
#     'Reasoning',
#     'Hypothesis discovery',
#     'Rule Learning'],
#    'portfolio_marker_highlight': ['ACL 2025']}],
#  'projects': [{'project_type': 'outside link',
#    'portfolio_src': ['../projects/Shiny app/Fig1.png',
#     '../projects/Shiny app/Fig2.png',
#     '../projects/Shiny app/Fig3.png'],
#    'portfolio_marker': ['Drag use', 'Data visualization', 'Shiny', 'R'],
#    'portfolio_marker_highlight': ['Shiny app'],
#    'title': 'Shiny app'},
#   {'title': 'Space simulator',
#    'project_type': None,
#    'portfolio_src': ['../projects/Space simulator/space.gif'],
#    'portfolio_marker': ['Physics', '3D Game', 'Unity', 'C#'],
#    'portfolio_marker_highlight': ['On going']},
#   {'title': 'EMO chat bot',
#    'project_type': 'pdf',
#    'portfolio_src': ['../projects/EMO chat bot/Fig1.png',
#     '../projects/EMO chat bot/Fig2.png',
#     '../projects/EMO chat bot/Fig3.png'],
#    'portfolio_marker': ['LLM Emotion Control',
#     'Representation Engineering',
#     'Role-play'],
#    'portfolio_marker_highlight': ['Trash talk LLM 🤬']},
#   {'project_type': 'outside link',
#    'portfolio_src': ['../projects/Battle-Royale game/topdown_2d.gif'],
#    'portfolio_marker': ['Physics', '3D Game', 'Unity', 'C#'],
#    'portfolio_marker_highlight': ['On going'],
#    'title': 'Battle-Royale game'}],
#  'links': [{'title': 'Google Scholar',
#    'project_type': 'outside link',
#    'portfolio_src': ['../links/Google Scholar/Fig1.png'],
#    'portfolio_marker': ['Google Scholar'],
#    'portfolio_marker_highlight': []},
#   {'title': 'Github',
#    'project_type': 'outside link',
#    'portfolio_src': ['../links/Github/Fig1.png'],
#    'portfolio_marker': ['Github'],
#    'portfolio_marker_highlight': []},
#   {'title': 'CV',
#    'project_type': 'new tab pdf',
#    'portfolio_src': ['../links/CV/Fig1.png'],
#    'portfolio_marker': ['CV'],
#    'portfolio_marker_highlight': []},
#   {'title': 'Linkedin',
#    'project_type': 'outside link',
#    'portfolio_src': ['../links/Linkedin/Fig1.png'],
#    'portfolio_marker': ['Linkedin'],
#    'portfolio_marker_highlight': []}]}

# %%
with open('construct_meta.json', 'w', encoding='utf-8') as f:
    json.dump(construct_json_file, f, ensure_ascii=False, indent=4)

# %%
# need to also update meta index and available_local_files.json
meta_index_file_path = '../../Profiles/meta_index.json'
# title: description
meta_index_content = {}
for proj_type in proj_types:
    for proj_meta in construct_json_file[proj_type]:
        proj_title = proj_meta['title']
        proj_path_ori = proj_meta['portfolio_src'][0].split('/')
        proj_path = os.path.join('..',proj_path_ori[1],proj_path_ori[2],'meta.json')
        with open(proj_path, 'r') as f:
            proj_meta_content = json.load(f)
        description = proj_meta_content['description']
        meta_index_entry = {proj_title:description}
        meta_index_content.update(meta_index_entry)
with open(meta_index_file_path,'w', encoding='utf-8') as f:
    json.dump(meta_index_content,f, ensure_ascii=False, indent=4)

# %%
# todo: 加上 portfolio 页面的引用
available_local_file_path = '../../Profiles/available_local_files.json'
path_prefix = '/assets/resources/'
available_file_content = []
for proj_type in proj_types:
    for proj_meta in construct_json_file[proj_type]:
        proj_title = proj_meta['title']
        proj_path_ori = proj_meta['portfolio_src'][0].split('/')
        proj_path = os.path.join('..',proj_path_ori[1],proj_path_ori[2],'meta.json')
        with open(proj_path, 'r') as f:
            proj_meta_content = json.load(f)
        src_file_name = proj_meta_content['src_file']
        if src_file_name is not None:
            if proj_meta_content['project_type'] == 'pdf':
                file_path = os.path.join(path_prefix,proj_path_ori[1],proj_path_ori[2],src_file_name)
                available_file_entry = {
                    'title':proj_title,
                    'project_type':proj_meta_content['project_type'],
                    'file_path':file_path
                }
                available_file_content.append(available_file_entry)
            if proj_meta_content['project_type'] == 'outside link':
                available_file_entry = {
                    'title':proj_title,
                    'project_type':proj_meta_content['project_type'],
                    'file_path':src_file_name
                }
                available_file_content.append(available_file_entry)
            if proj_meta_content['project_type'] == 'new tab pdf':
                available_file_entry = {
                    'title':proj_title,
                    'project_type':proj_meta_content['project_type'],
                    'file_path':src_file_name
                }
                available_file_content.append(available_file_entry)
# portfolio file entry
portfolio_entry = {
                   "title": "Home page",
                   "project_type": "html",
                   "file_path": "/assets/resources/portfolio/portfolio.html"
                  }
available_file_content.append(portfolio_entry)
with open(available_local_file_path,'w', encoding='utf-8') as f:
    json.dump(available_file_content,f, ensure_ascii=False, indent=4)
available_file_content
# Out:
# 123
# [{'title': 'Abductive Reasoning Evaluation', 'project_type': 'pdf', 'file_path': '/assets/resources/publications/Abductive Reasoning Evaluation/Abduction Reasoning Evaluation.pdf'}, {'title': 'Eifficient RAG', 'project_type': 'pdf', 'file_path': '/assets/resources/publications/Eifficient RAG/Eifficient RAG.pdf'}, {'title': 'LLM hypothesis discovery survey', 'project_type': 'pdf', 'file_path': '/assets/resources/publications/LLM hypothesis discovery survey/reasoning_survey_paper.pdf'}, {'title': 'Contact tracing', 'project_type': 'pdf', 'file_path': '/assets/resources/publications/Contact tracing/contact_tracing_paper.pdf'}, {'title': 'IDEA', 'project_type': 'pdf', 'file_path': '/assets/resources/publications/IDEA/IDEA_paper.pdf'}, {'title': 'Shiny app', 'project_type': 'outside link', 'file_path': 'https://meanstudent.shinyapps.io/new_shiny/'}, {'title': 'EMO chat bot', 'project_type': 'pdf', 'file_path': '/assets/resources/projects/EMO chat bot/EMO chat bot.pdf'}, {'title': 'Battle-Royale game', 'project_type': 'outside link', 'file_path': 'https://garythekid.github.io/project-topdownPixel.html'}, {'title': 'Google Scholar', 'project_type': 'outside link', 'file_path': 'https://scholar.google.com/citations?hl=zh-CN&user=afzTrgEAAAAJ'}, {'title': 'Github', 'project_type': 'outside link', 'file_path': 'https://github.com/KaiyuHe998'}, {'title': 'Linkedin', 'project_type': 'outside link', 'file_path': 'https://www.linkedin.com/in/kaiyuhe998/'}, {'title': 'Home page', 'project_type': 'html', 'file_path': '/assets/resources/portfolio/portfolio.html'}]

# %%
# # key starts with _ will not be passed to portfolio construction
# each_meta_file = {
#     'title':'',                                              # short title for agent and this will be the keyword that can be jumped into a certain project
#     'description':'',                                        # whole description
#     'project_type':''                                        # pdf, html, out sorce link
#     '_chapters':{                       
#         'chapter_name_1': {"page":1, "chapter description"}, # need to know main content of this chapter and why need to jump to here
#         'chapter_name_2': {""}
#     },
#     'portfolio_asset':[""],
#     '_keywords':{
#         "keyword": {function}                                # short title for agent and this will be the keyword that can be jumped into a certain project
#     }
    
# }

# %%
# construct_metadata = {
#     "publications":{
#         [
#             {
#                 'title':'',
#                 'description':'',
#                 'project_type': '',         # outside link # local file 
#                 'short_show_file':'',       # pic or 
#                 '',
#             },
#             {
                
#             }
#         ]
        
#     }
#     "projects":{
#         'title':'',
#         'description':'',
#         'project_type': ,  # outside link # local file 
#         'src_file':'',      
#         ''
#     }

# }
